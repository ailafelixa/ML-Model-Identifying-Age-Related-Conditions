# %% [markdown]
# <a href="https://www.kaggle.com/code/ailafelixa/icr-iarc-pre-process-cat-boost-classifier?scriptVersionId=131374407" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Importing relevant packages

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
import copy

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
import xgboost as xgb
import catboost
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Importing the data

# %%
# Load the data
train = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/train.csv')
test = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/test.csv')
greeks = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/greeks.csv')
sample_submission = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/sample_submission.csv')

# %% [markdown]
# ## Descriptive and Exploratory Data Analysis
#
# First of all, lets take a look at the data

# %%
train.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...        FL        FR  \
# 0  0.699861  0.025578   9.812214    5.555634  ...  7.298162   1.73855
# 1  3.632190  0.025578  13.517790    1.229900  ...  0.173229   0.49706
# 2  6.732840  0.025578  12.824570    1.229900  ...  7.709560   0.97556
# 3  3.685344  0.025578  11.053708    1.229900  ...  6.122162   0.49706
# 4  3.942255  0.054810   3.396778  102.151980  ...  8.153058  48.50134
#
#          FS         GB          GE            GF         GH         GI  \
# 0  0.094822  11.339138   72.611063   2003.810319  22.136229  69.834944
# 1  0.568932   9.292698   72.611063  27981.562750  29.135430  32.131996
# 2  1.198821  37.077772   88.609437  13676.957810  28.022851  35.192676
# 3  0.284466  18.529584   82.416803   2094.262452  39.948656  90.493248
# 4  0.121914  16.408728  146.109943   8524.370502  45.381316  36.262628
#
#           GL  Class
# 0   0.120343      1
# 1  21.978000      0
# 2   0.196941      0
# 3   0.155829      0
# 4   0.096614      1
#
# [5 rows x 58 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 58 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      617 non-null    object
#  1   AB      617 non-null    float64
#  2   AF      617 non-null    float64
#  3   AH      617 non-null    float64
#  4   AM      617 non-null    float64
#  5   AR      617 non-null    float64
#  6   AX      617 non-null    float64
#  7   AY      617 non-null    float64
#  8   AZ      617 non-null    float64
#  9   BC      617 non-null    float64
#  10  BD      617 non-null    float64
#  11  BN      617 non-null    float64
#  12  BP      617 non-null    float64
#  13  BQ      557 non-null    float64
#  14  BR      617 non-null    float64
#  15  BZ      617 non-null    float64
#  16  CB      615 non-null    float64
#  17  CC      614 non-null    float64
#  18  CD      617 non-null    float64
#  19  CF      617 non-null    float64
#  20  CH      617 non-null    float64
#  21  CL      617 non-null    float64
#  22  CR      617 non-null    float64
#  23  CS      617 non-null    float64
#  24  CU      617 non-null    float64
#  25  CW      617 non-null    float64
#  26  DA      617 non-null    float64
#  27  DE      617 non-null    float64
#  28  DF      617 non-null    float64
#  29  DH      617 non-null    float64
#  30  DI      617 non-null    float64
#  31  DL      617 non-null    float64
#  32  DN      617 non-null    float64
#  33  DU      616 non-null    float64
#  34  DV      617 non-null    float64
#  35  DY      617 non-null    float64
#  36  EB      617 non-null    float64
#  37  EE      617 non-null    float64
#  38  EG      617 non-null    float64
#  39  EH      617 non-null    float64
#  40  EJ      617 non-null    object
#  41  EL      557 non-null    float64
#  42  EP      617 non-null    float64
#  43  EU      617 non-null    float64
#  44  FC      616 non-null    float64
#  45  FD      617 non-null    float64
#  46  FE      617 non-null    float64
#  47  FI      617 non-null    float64
#  48  FL      616 non-null    float64
#  49  FR      617 non-null    float64
#  50  FS      615 non-null    float64
#  51  GB      617 non-null    float64
#  52  GE      617 non-null    float64
#  53  GF      617 non-null    float64
#  54  GH      617 non-null    float64
#  55  GI      617 non-null    float64
#  56  GL      616 non-null    float64
#  57  Class   617 non-null    int64
# dtypes: float64(55), int64(1), object(2)
# memory usage: 279.7+ KB

# %% [markdown]
# The majority of our columns are float64. We have one column ('EJ') with the 'object' type. It is interesting to verify why this column have this type.
# Columns like 'BQ' and 'EL' have more than 50 lines with null values. We will need to take a look at these to verify if some kind of imputation is needed.

# %% [markdown]
# ### Are our train dataset balanced or disbalanced?

# %%
train['Class'].value_counts()
# Out:
# 0    509
# 1    108
# Name: Class, dtype: int64

# %% [markdown]
# Our dataset is highly disbalanced. The number of negative cases is nearly 5 times higher than the number of positive examples.

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# ### Spliting the train dataset into train and validation

# %%
#First, let split the dataset into train and validation
#As our dataset is disbalanced, we will look-forward to maintain the same variable frequencies

X = copy.deepcopy(train.drop('Id', axis=1))
y = X.pop('Class')

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# ### Pre-processing the column with the 'object' type

# %%
#First, lets see how many different values the column with 'object' type have

train['EJ'].value_counts()
# Out:
# B    395
# A    222
# Name: EJ, dtype: int64

# %% [markdown]
# There are two distinct values in this column. In this case we can simply replace the values for 1 and 0

# %%
#Transforming the column with 'object' type

X_train['EJ'] = X_train['EJ'].replace({'A': 1, 'B': 0})
X_valid['EJ'] = X_valid['EJ'].replace({'A': 1, 'B': 0})

# %%
X_train['EJ'].value_counts()
# Out:
# 0    318
# 1    175
# Name: EJ, dtype: int64

# %% [markdown]
# ## Applying standard scaler

# %%
X_train.describe()
# Out:
#                AB            AF           AH          AM          AR  \
# count  493.000000    493.000000   493.000000  493.000000  493.000000
# mean     0.483672   3451.565811   115.762651   41.105671    9.883313
# std      0.494641   2005.366931   116.261447   75.086262    8.676564
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.252107   2184.242390    85.200147   12.270314    8.138688
# 50%      0.350386   3045.933000    85.200147   20.505237    8.138688
# 75%      0.559763   4376.465940   109.742109   42.221401    8.138688
# max      6.161666  18964.472780  1910.123198  630.518230  173.534448
#
#                AX          AY          AZ           BC           BD   ...  \
# count  493.000000  493.000000  493.000000   493.000000    493.000000  ...
# mean     5.551565    0.063965   10.642512     8.740344   5442.788608  ...
# std      2.595000    0.465331    4.195261    72.693664   3296.277834  ...
# min      0.699861    0.025578    3.396778     1.229900   2103.143780  ...
# 25%      4.101717    0.025578    8.173694     1.229900   4158.011980  ...
# 50%      5.031912    0.025578   10.593662     1.229900   5083.821270  ...
# 75%      6.511365    0.038367   13.057744     4.891488   6129.660335  ...
# max     38.270880   10.315851   30.192882  1463.693448  53060.599240  ...
#
#                FI          FL           FR          FS          GB  \
# count  493.000000  492.000000   493.000000  491.000000  493.000000
# mean    10.099123    5.535944     4.028661    0.437762   20.971784
# std      2.973876   12.246720    56.098927    1.448711   10.167604
# min      3.583450    0.173229     0.497060    0.067730    4.102182
# 25%      8.495533    0.173229     0.497060    0.067730   14.464610
# 50%      9.862757    3.000258     1.120850    0.257374   19.041194
# 75%     11.329215    6.122686     1.507420    0.541840   25.515386
# max     35.851039  137.932739  1244.227020   31.365763  135.781294
#
#                 GE             GF          GH          GI          GL
# count   493.000000     493.000000  493.000000  493.000000  492.000000
# mean    129.428170   14228.741789   31.570198   50.623218    8.463101
# std     144.256400   18288.411077    9.889031   36.053497   10.291116
# min      72.611063      13.038894    9.432735    0.897628    0.001129
# 25%      72.611063    2798.992584   25.113029   23.065696    0.123954
# 50%      72.611063    7521.784092   30.750344   41.416916    0.337827
# 75%     126.767900   19035.709240   37.210000   67.931664   21.978000
# max    1497.351958  143790.071200   81.210825  191.194764   21.978000
#
# [8 rows x 56 columns]

# %% [markdown]
# As we can see, we have values with a huge different scales. Lets apply a standard scale before follow with the other pre-processing procedures

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(X_train)
column_names = X_train.columns.tolist()

# Transform the training data
X_train_scaled = pd.DataFrame(scaler.transform(X_train), columns=column_names)

# Transform the test data using the same scaler
X_valid_scaled = pd.DataFrame(scaler.transform(X_valid), columns=column_names)

X_train = X_train_scaled
X_valid = X_valid_scaled

# %% [markdown]
# ## Handling missing values

# %%
#Identifying column with nulls 

cols_with_missings = [col for col in X_train.columns
                        if X_train[col].isnull().any()]

print('Columns with nulls: ', cols_with_missings)

#Imputing using SimpleImputer

my_imputer = SimpleImputer(strategy="mean")
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

X_train = imputed_X_train
X_valid = imputed_X_valid
# Out:
# Columns with nulls:  ['BQ', 'CB', 'CC', 'DU', 'EL', 'FC', 'FL', 'FS', 'GL']

# %%
#Verifying if there is any null

cols_with_missings = [col for col in X_train.columns
                        if X_train[col].isnull().any()]
print('Columns with nulls: ', cols_with_missings)
# Out:
# Columns with nulls:  []

# %% [markdown]
# ## Balacing the dataset using SMOTE

# %%
smote = SMOTE(sampling_strategy=1.0, random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
y_train.value_counts()
# Out:
# 0    407
# 1    407
# Name: Class, dtype: int64

# %% [markdown]
# ## Selecting the model type

# %%
# Fit CatBoost model
cat_model = catboost.CatBoostClassifier()
cat_model.fit(X_train, y_train, verbose=False)

# Predict on the test set and calculate Log Loss
cat_pred_proba = cat_model.predict_proba(X_valid)[::,1]
cat_ll = metrics.log_loss(y_valid, cat_pred_proba)

# Calculate ROC curve and AUC score for CatBoost
cat_fpr, cat_tpr, _ = metrics.roc_curve(y_valid, cat_pred_proba)
cat_auc = metrics.auc(cat_fpr, cat_tpr)

# Fit LightGBM model
lgb_model = lgb.LGBMClassifier()
lgb_model.fit(X_train, y_train, verbose=False)

# Predict on the test set and calculate Log Loss
lgb_pred_proba = lgb_model.predict_proba(X_valid)[::,1]
lgb_ll = metrics.log_loss(y_valid, lgb_pred_proba)

# Calculate ROC curve and AUC score for LightGBM
lgb_fpr, lgb_tpr, _ = metrics.roc_curve(y_valid, lgb_pred_proba)
lgb_auc = metrics.auc(lgb_fpr, lgb_tpr)

# Fit XGBoost model
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train, verbose=False)

# Predict on the test set and calculate LogLoss
xgb_pred_proba = xgb_model.predict_proba(X_valid)[::,1]
xgb_ll = metrics.log_loss(y_valid, xgb_pred_proba)

# Calculate ROC curve and AUC score for XGBoost
xgb_fpr, xgb_tpr, _ = metrics.roc_curve(y_valid, xgb_pred_proba)
xgb_auc = metrics.auc(xgb_fpr, xgb_tpr)

# Fit Random Forest model
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

# Predict on the test set and calculate LogLoss
rf_pred_proba = rf_model.predict_proba(X_valid)[::,1]
rf_ll = metrics.log_loss(y_valid, rf_pred_proba)

# Calculate ROC curve and AUC score for RF
rf_fpr, rf_tpr, _ = metrics.roc_curve(y_valid, rf_pred_proba)
rf_auc = metrics.auc(rf_fpr, rf_tpr)


# Print the results
print("CatBoost LogLoss: {:.2f}".format(cat_ll))
print("CatBoost AUC: {:.2f}".format(cat_auc))
print("-"*40)
print("LightGBM LogLoss: {:.2f}".format(lgb_ll))
print("LightGBM AUC: {:.2f}".format(lgb_auc))
print("-"*40)
print("Random Forest LogLoss: {:.2f}".format(rf_ll))
print("Random Forest AUC: {:.2f}".format(rf_auc))
print("-"*40)
print("XGBoost LogLoss: {:.2f}".format(xgb_ll))
print("XGBoost AUC: {:.2f}".format(xgb_auc))
# Out:
# CatBoost LogLoss: 0.19
# CatBoost AUC: 0.97
# ----------------------------------------
# LightGBM LogLoss: 0.30
# LightGBM AUC: 0.96
# ----------------------------------------
# Random Forest LogLoss: 0.28
# Random Forest AUC: 0.95
# ----------------------------------------
# XGBoost LogLoss: 0.26
# XGBoost AUC: 0.96

# %% [markdown]
# Let's follow with the CatBoost classifier!

# %%
model = catboost.CatBoostClassifier()
model.fit(X_train, y_train, verbose=False)

y_pred_proba = model.predict_proba(X_valid)
log_loss = metrics.log_loss(y_valid, y_pred_proba)
print("Log loss: ", log_loss)
# Out:
# Log loss:  0.19383100548033255

# %% [markdown]
# Let's test some new params

# %%
model = catboost.CatBoostClassifier(eval_metric='Logloss',
                                    depth=4,
                                    n_estimators=500,
                                    )

model.fit(X_train, y_train, verbose=False)

y_pred_proba = model.predict_proba(X_valid)
log_loss = metrics.log_loss(y_valid, y_pred_proba)
print("Log loss: ", log_loss)
# Out:
# Log loss:  0.1892589357772616

# %%
# Initialize the CatBoostClassifier with L1 regularization
model = catboost.CatBoostClassifier(eval_metric='Logloss',
                           depth=4,
                           n_estimators=500,
                           l2_leaf_reg=1,  # L1 regularization parameter
                           random_seed=1)

# Fit the model to the training data
model.fit(X_train, y_train, verbose=False)

# Get feature importances (L1 regularization)
feature_importances = np.abs(model.feature_importances_)

# Create a dictionary mapping feature names to importances
importance_dict = dict(zip(X_train.columns, feature_importances))

# Sort the feature importances in descending order
sorted_importances = sorted(importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print the feature importances
for feature, importance in sorted_importances:
    print(feature, importance)
    
y_pred_proba = model.predict_proba(X_valid)
log_loss = metrics.log_loss(y_valid, y_pred_proba)
print("Log loss: ", log_loss)
# Out:
# DU 20.00365591419002
# AB 9.262896843034882
# BQ 7.060639815757501
# CR 5.266313767885252
# EB 3.2084207330940253
# EU 3.072283645828158
# CD  2.8357015756218034
# AF 2.8163280959070733
# DA 2.7662267635959483
# GL 2.6848406441506167
# BC 2.557841182421223
# CC 2.533165939871479
# FL 2.1629631731951275
# DY 2.0531424636791975
# DL 2.0007255498163787
# DN 1.6788064254448603
# BN 1.6506982999941369
# EE 1.55358316127208
# EP 1.4086350965563206
# CB 1.3911477937861336
# DH 1.3075809411183255
# EL 1.2793753892375597
# CH 1.2521997537023386
# AM 1.1411745802855244
# DE 1.1245754348511534
# FI 1.1096281573832059
# CU 1.0872334218118747
# DF 1.0403337351443835
# EH 0.9835553210304959
# CF 0.9246957760935975
# FR 0.9194900777550807
# FE 0.8111246538570905
# FD  0.7644933498967662
# CW  0.7384522834463644
# AX 0.670488452709826
# EJ 0.6433493397007402
# CS 0.6391840930980888
# EG 0.5238648573248533
# GE 0.4593079650320112
# DV 0.452010291482242
# BP 0.4387004053765765
# GI 0.4339217676194196
# AR 0.3941264543808079
# BZ 0.3514766211214465
# CL 0.3443027857022532
# BR 0.3272333220288229
# FC 0.31899345201743956
# GH 0.25189530983867436
# AH 0.21572268411940684
# AZ 0.20779446360383536
# AY 0.19929631648089985
# GF 0.19591783676135524
# GB 0.15514638442787929
# DI 0.130159191540844
# BD  0.1130346147752099
# FS 0.08214363014138458
# Log loss:  0.18319483332141961

# %%
# Initialize the CatBoostClassifier with L1 regularization
model = catboost.CatBoostClassifier(eval_metric='Logloss',
                           depth=4,
                           n_estimators=500,
                           l2_leaf_reg=1,  # L1 regularization parameter
                           random_seed=1)

# Fit the model to the training data
model.fit(X_train, y_train, verbose=False)

# Get feature importances (L1 regularization)
feature_importances = np.abs(model.feature_importances_)

# Create a dictionary mapping feature names to importances
importance_dict = dict(zip(X_train.columns, feature_importances))

# Set a threshold for importance
threshold = 0.5

# Drop the features with importance below the threshold
selected_features = [feature for feature, importance in importance_dict.items() if importance >= threshold]

# Filter the datasets with the selected features
X_train_filtered = X_train[selected_features]
X_valid_filtered = X_valid[selected_features]

# Print the dropped features
dropped_features = [feature for feature in X_train.columns if feature not in selected_features]
print("Dropped features:")
print(dropped_features)
# Out:
# Dropped features:
# ['AH', 'AR', 'AY', 'AZ', 'BD ', 'BP', 'BR', 'BZ', 'CL', 'DI', 'DV', 'FC', 'FS', 'GB', 'GE', 'GF', 'GH', 'GI']

# %%
model.fit(X_train_filtered, y_train, verbose=False)

y_pred_proba = model.predict_proba(X_valid_filtered)
log_loss = metrics.log_loss(y_valid, y_pred_proba)
print("Log loss: ", log_loss)
# Out:
# Log loss:  0.18022987527094997

# %%
X_train = X_train_filtered
X_valid = X_valid_filtered

# %% [markdown]
# ## Generating the final predictions

# %%
#Pre-processing the test dataset
X_test = copy.deepcopy(test)
X_test = X_test.drop('Id', axis=1)
#Applying the numbers to the object column
X_test['EJ'] = test['EJ'].replace({'A': 1, 'B': 0})

# %%
#Imputing features with null values

cols_with_missings = [col for col in X_test.columns
                        if X_test[col].isnull().any()]

print('Columns with nulls: ', cols_with_missings)

#Imputing using SimpleImputer

my_imputer = SimpleImputer(strategy="mean")
imputed_test = pd.DataFrame(my_imputer.fit_transform(X_test))

imputed_test.columns = X_test.columns

X_test = imputed_test
# Out:
# Columns with nulls:  []

# %%
X_combined = pd.concat([X_train, X_valid], axis=0)

# %%
y_combined = pd.concat([y_train, y_valid], axis=0)

# %%
model.fit(X_combined,y_combined)
# Out:
# 0:	learn: 0.6677553	total: 2.84ms	remaining: 1.42s
# 1:	learn: 0.6349290	total: 5.61ms	remaining: 1.4s
# 2:	learn: 0.6109247	total: 8.18ms	remaining: 1.35s
# 3:	learn: 0.5888601	total: 10.6ms	remaining: 1.31s
# 4:	learn: 0.5681910	total: 13ms	remaining: 1.29s
# 5:	learn: 0.5487293	total: 15.5ms	remaining: 1.27s
# 6:	learn: 0.5343916	total: 17.9ms	remaining: 1.26s
# 7:	learn: 0.5161711	total: 20.4ms	remaining: 1.25s
# 8:	learn: 0.5008905	total: 22.9ms	remaining: 1.25s
# 9:	learn: 0.4915873	total: 25.4ms	remaining: 1.24s
# 10:	learn: 0.4772918	total: 27.8ms	remaining: 1.23s
# 11:	learn: 0.4636592	total: 30.2ms	remaining: 1.23s
# 12:	learn: 0.4464776	total: 32.4ms	remaining: 1.22s
# 13:	learn: 0.4342310	total: 34.7ms	remaining: 1.2s
# 14:	learn: 0.4231787	total: 36.9ms	remaining: 1.19s
# 15:	learn: 0.4107874	total: 39.5ms	remaining: 1.19s
# 16:	learn: 0.3991171	total: 42.3ms	remaining: 1.2s
# 17:	learn: 0.3884456	total: 44.7ms	remaining: 1.2s
# 18:	learn: 0.3797309	total: 47.2ms	remaining: 1.19s
# 19:	learn: 0.3709960	total: 49.9ms	remaining: 1.2s
# 20:	learn: 0.3634474	total: 52.4ms	remaining: 1.2s
# 21:	learn: 0.3550040	total: 54.7ms	remaining: 1.19s
# 22:	learn: 0.3501213	total: 59.7ms	remaining: 1.24s
# 23:	learn: 0.3450990	total: 64.3ms	remaining: 1.27s
# 24:	learn: 0.3382457	total: 78.2ms	remaining: 1.49s
# 25:	learn: 0.3334938	total: 81.2ms	remaining: 1.48s
# 26:	learn: 0.3271563	total: 83.9ms	remaining: 1.47s
# 27:	learn: 0.3213942	total: 86.6ms	remaining: 1.46s
# 28:	learn: 0.3161726	total: 89.3ms	remaining: 1.45s
# 29:	learn: 0.3122919	total: 92.1ms	remaining: 1.44s
# 30:	learn: 0.3067322	total: 94.9ms	remaining: 1.44s
# 31:	learn: 0.3024856	total: 97.5ms	remaining: 1.43s
# 32:	learn: 0.2980093	total: 99.9ms	remaining: 1.41s
# 33:	learn: 0.2941485	total: 103ms	remaining: 1.4s
# 34:	learn: 0.2887048	total: 105ms	remaining: 1.4s
# 35:	learn: 0.2846475	total: 108ms	remaining: 1.39s
# 36:	learn: 0.2777077	total: 110ms	remaining: 1.38s
# 37:	learn: 0.2731124	total: 113ms	remaining: 1.37s
# 38:	learn: 0.2680916	total: 116ms	remaining: 1.37s
# 39:	learn: 0.2655171	total: 118ms	remaining: 1.36s
# 40:	learn: 0.2623800	total: 121ms	remaining: 1.35s
# 41:	learn: 0.2589569	total: 124ms	remaining: 1.35s
# 42:	learn: 0.2560224	total: 126ms	remaining: 1.34s
# 43:	learn: 0.2528803	total: 129ms	remaining: 1.33s
# 44:	learn: 0.2509037	total: 131ms	remaining: 1.33s
# 45:	learn: 0.2485094	total: 134ms	remaining: 1.32s
# 46:	learn: 0.2446569	total: 137ms	remaining: 1.32s
# 47:	learn: 0.2423234	total: 140ms	remaining: 1.31s
# 48:	learn: 0.2386581	total: 142ms	remaining: 1.31s
# 49:	learn: 0.2352465	total: 145ms	remaining: 1.3s
# 50:	learn: 0.2325152	total: 148ms	remaining: 1.3s
# 51:	learn: 0.2303202	total: 150ms	remaining: 1.29s
# 52:	learn: 0.2283710	total: 153ms	remaining: 1.29s
# 53:	learn: 0.2258241	total: 155ms	remaining: 1.28s
# 54:	learn: 0.2236716	total: 158ms	remaining: 1.28s
# 55:	learn: 0.2214860	total: 160ms	remaining: 1.27s
# 56:	learn: 0.2196327	total: 163ms	remaining: 1.27s
# 57:	learn: 0.2168947	total: 166ms	remaining: 1.26s
# 58:	learn: 0.2147288	total: 168ms	remaining: 1.26s
# 59:	learn: 0.2130595	total: 171ms	remaining: 1.25s
# 60:	learn: 0.2104489	total: 174ms	remaining: 1.25s
# 61:	learn: 0.2080586	total: 176ms	remaining: 1.24s
# 62:	learn: 0.2056718	total: 179ms	remaining: 1.24s
# 63:	learn: 0.2039420	total: 181ms	remaining: 1.24s
# 64:	learn: 0.2017787	total: 184ms	remaining: 1.23s
# 65:	learn: 0.1995451	total: 187ms	remaining: 1.23s
# 66:	learn: 0.1973206	total: 189ms	remaining: 1.22s
# 67:	learn: 0.1951825	total: 192ms	remaining: 1.22s
# 68:	learn: 0.1932289	total: 194ms	remaining: 1.21s
# 69:	learn: 0.1917119	total: 198ms	remaining: 1.22s
# 70:	learn: 0.1892078	total: 201ms	remaining: 1.22s
# 71:	learn: 0.1872840	total: 204ms	remaining: 1.21s
# 72:	learn: 0.1857585	total: 207ms	remaining: 1.21s
# 73:	learn: 0.1844408	total: 209ms	remaining: 1.2s
# 74:	learn: 0.1825903	total: 212ms	remaining: 1.2s
# 75:	learn: 0.1809058	total: 214ms	remaining: 1.2s
# 76:	learn: 0.1791481	total: 217ms	remaining: 1.19s
# 77:	learn: 0.1778364	total: 219ms	remaining: 1.19s
# 78:	learn: 0.1768064	total: 222ms	remaining: 1.18s
# 79:	learn: 0.1749118	total: 224ms	remaining: 1.18s
# 80:	learn: 0.1738044	total: 227ms	remaining: 1.17s
# 81:	learn: 0.1726793	total: 229ms	remaining: 1.17s
# 82:	learn: 0.1711479	total: 231ms	remaining: 1.16s
# 83:	learn: 0.1690189	total: 234ms	remaining: 1.16s
# 84:	learn: 0.1675967	total: 236ms	remaining: 1.15s
# 85:	learn: 0.1664322	total: 239ms	remaining: 1.15s
# 86:	learn: 0.1655356	total: 241ms	remaining: 1.15s
# 87:	learn: 0.1638913	total: 244ms	remaining: 1.14s
# 88:	learn: 0.1629204	total: 246ms	remaining: 1.14s
# 89:	learn: 0.1614709	total: 248ms	remaining: 1.13s
# 90:	learn: 0.1602445	total: 251ms	remaining: 1.13s
# 91:	learn: 0.1589671	total: 255ms	remaining: 1.13s
# 92:	learn: 0.1579708	total: 258ms	remaining: 1.13s
# 93:	learn: 0.1562862	total: 261ms	remaining: 1.13s
# 94:	learn: 0.1544691	total: 263ms	remaining: 1.12s
# 95:	learn: 0.1525341	total: 266ms	remaining: 1.12s
# 96:	learn: 0.1513420	total: 268ms	remaining: 1.11s
# 97:	learn: 0.1494472	total: 271ms	remaining: 1.11s
# 98:	learn: 0.1479098	total: 273ms	remaining: 1.1s
# 99:	learn: 0.1469864	total: 276ms	remaining: 1.1s
# 100:	learn: 0.1457227	total: 278ms	remaining: 1.1s
# 101:	learn: 0.1443340	total: 281ms	remaining: 1.09s
# 102:	learn: 0.1429303	total: 283ms	remaining: 1.09s
# 103:	learn: 0.1419624	total: 286ms	remaining: 1.09s
# 104:	learn: 0.1409719	total: 288ms	remaining: 1.08s
# 105:	learn: 0.1395758	total: 290ms	remaining: 1.08s
# 106:	learn: 0.1385064	total: 293ms	remaining: 1.07s
# 107:	learn: 0.1377283	total: 295ms	remaining: 1.07s
# 108:	learn: 0.1370088	total: 298ms	remaining: 1.07s
# 109:	learn: 0.1356735	total: 300ms	remaining: 1.06s
# 110:	learn: 0.1349602	total: 302ms	remaining: 1.06s
# 111:	learn: 0.1329233	total: 305ms	remaining: 1.05s
# 112:	learn: 0.1316305	total: 307ms	remaining: 1.05s
# 113:	learn: 0.1308754	total: 309ms	remaining: 1.05s
# 114:	learn: 0.1295399	total: 312ms	remaining: 1.04s
# 115:	learn: 0.1283599	total: 314ms	remaining: 1.04s
# 116:	learn: 0.1274562	total: 317ms	remaining: 1.04s
# 117:	learn: 0.1264237	total: 319ms	remaining: 1.03s
# 118:	learn: 0.1252390	total: 322ms	remaining: 1.03s
# 119:	learn: 0.1244027	total: 325ms	remaining: 1.03s
# 120:	learn: 0.1234158	total: 327ms	remaining: 1.02s
# 121:	learn: 0.1227276	total: 330ms	remaining: 1.02s
# 122:	learn: 0.1215592	total: 332ms	remaining: 1.02s
# 123:	learn: 0.1207537	total: 335ms	remaining: 1.01s
# 124:	learn: 0.1197313	total: 337ms	remaining: 1.01s
# 125:	learn: 0.1187897	total: 340ms	remaining: 1.01s
# 126:	learn: 0.1181080	total: 342ms	remaining: 1s
# 127:	learn: 0.1175172	total: 345ms	remaining: 1s
# 128:	learn: 0.1168558	total: 347ms	remaining: 999ms
# 129:	learn: 0.1156319	total: 350ms	remaining: 996ms
# 130:	learn: 0.1143428	total: 352ms	remaining: 992ms
# 131:	learn: 0.1132081	total: 355ms	remaining: 989ms
# 132:	learn: 0.1127265	total: 357ms	remaining: 985ms
# 133:	learn: 0.1118792	total: 360ms	remaining: 982ms
# 134:	learn: 0.1111566	total: 362ms	remaining: 979ms
# 135:	learn: 0.1104703	total: 365ms	remaining: 976ms
# 136:	learn: 0.1097267	total: 367ms	remaining: 973ms
# 137:	learn: 0.1088735	total: 370ms	remaining: 970ms
# 138:	learn: 0.1084130	total: 372ms	remaining: 966ms
# 139:	learn: 0.1072442	total: 375ms	remaining: 963ms
# 140:	learn: 0.1062334	total: 377ms	remaining: 960ms
# 141:	learn: 0.1056251	total: 380ms	remaining: 957ms
# 142:	learn: 0.1048433	total: 382ms	remaining: 954ms
# 143:	learn: 0.1041106	total: 385ms	remaining: 951ms
# 144:	learn: 0.1033208	total: 387ms	remaining: 948ms
# 145:	learn: 0.1024730	total: 389ms	remaining: 944ms
# 146:	learn: 0.1017926	total: 394ms	remaining: 945ms
# 147:	learn: 0.1009171	total: 396ms	remaining: 943ms
# 148:	learn: 0.1001033	total: 399ms	remaining: 940ms
# 149:	learn: 0.0994158	total: 401ms	remaining: 936ms
# 150:	learn: 0.0985859	total: 404ms	remaining: 933ms
# 151:	learn: 0.0979534	total: 406ms	remaining: 930ms
# 152:	learn: 0.0973271	total: 409ms	remaining: 927ms
# 153:	learn: 0.0964443	total: 411ms	remaining: 924ms
# 154:	learn: 0.0956798	total: 414ms	remaining: 920ms
# 155:	learn: 0.0950376	total: 416ms	remaining: 917ms
# 156:	learn: 0.0943281	total: 418ms	remaining: 914ms
# 157:	learn: 0.0939509	total: 421ms	remaining: 911ms
# 158:	learn: 0.0933174	total: 424ms	remaining: 908ms
# 159:	learn: 0.0927682	total: 426ms	remaining: 905ms
# 160:	learn: 0.0922929	total: 428ms	remaining: 902ms
# 161:	learn: 0.0915867	total: 431ms	remaining: 900ms
# 162:	learn: 0.0910281	total: 434ms	remaining: 897ms
# 163:	learn: 0.0907056	total: 436ms	remaining: 894ms
# 164:	learn: 0.0900618	total: 439ms	remaining: 891ms
# 165:	learn: 0.0896952	total: 441ms	remaining: 888ms
# 166:	learn: 0.0889912	total: 444ms	remaining: 885ms
# 167:	learn: 0.0883728	total: 446ms	remaining: 882ms
# 168:	learn: 0.0878055	total: 450ms	remaining: 881ms
# 169:	learn: 0.0869364	total: 452ms	remaining: 878ms
# 170:	learn: 0.0862770	total: 455ms	remaining: 875ms
# 171:	learn: 0.0856628	total: 457ms	remaining: 872ms
# 172:	learn: 0.0850687	total: 460ms	remaining: 870ms
# 173:	learn: 0.0844241	total: 463ms	remaining: 867ms
# 174:	learn: 0.0834839	total: 465ms	remaining: 864ms
# 175:	learn: 0.0824544	total: 468ms	remaining: 861ms
# 176:	learn: 0.0818695	total: 470ms	remaining: 858ms
# 177:	learn: 0.0812467	total: 473ms	remaining: 855ms
# 178:	learn: 0.0805193	total: 475ms	remaining: 852ms
# 179:	learn: 0.0798881	total: 477ms	remaining: 849ms
# 180:	learn: 0.0792920	total: 480ms	remaining: 846ms
# 181:	learn: 0.0787476	total: 482ms	remaining: 843ms
# 182:	learn: 0.0783358	total: 485ms	remaining: 840ms
# 183:	learn: 0.0777663	total: 487ms	remaining: 837ms
# 184:	learn: 0.0771509	total: 490ms	remaining: 834ms
# 185:	learn: 0.0766368	total: 492ms	remaining: 831ms
# 186:	learn: 0.0758825	total: 495ms	remaining: 828ms
# 187:	learn: 0.0753697	total: 497ms	remaining: 825ms
# 188:	learn: 0.0745056	total: 500ms	remaining: 822ms
# 189:	learn: 0.0740069	total: 502ms	remaining: 819ms
# 190:	learn: 0.0733995	total: 505ms	remaining: 816ms
# 191:	learn: 0.0729122	total: 507ms	remaining: 813ms
# 192:	learn: 0.0722394	total: 509ms	remaining: 810ms
# 193:	learn: 0.0718240	total: 512ms	remaining: 807ms
# 194:	learn: 0.0713145	total: 514ms	remaining: 804ms
# 195:	learn: 0.0706143	total: 517ms	remaining: 801ms
# 196:	learn: 0.0701492	total: 519ms	remaining: 798ms
# 197:	learn: 0.0695176	total: 522ms	remaining: 796ms
# 198:	learn: 0.0690599	total: 524ms	remaining: 793ms
# 199:	learn: 0.0683355	total: 526ms	remaining: 790ms
# 200:	learn: 0.0677160	total: 529ms	remaining: 787ms
# 201:	learn: 0.0672859	total: 531ms	remaining: 784ms
# 202:	learn: 0.0667802	total: 534ms	remaining: 781ms
# 203:	learn: 0.0664166	total: 536ms	remaining: 778ms
# 204:	learn: 0.0658235	total: 538ms	remaining: 775ms
# 205:	learn: 0.0654123	total: 541ms	remaining: 772ms
# 206:	learn: 0.0651191	total: 543ms	remaining: 769ms
# 207:	learn: 0.0647653	total: 546ms	remaining: 766ms
# 208:	learn: 0.0644766	total: 548ms	remaining: 763ms
# 209:	learn: 0.0641783	total: 550ms	remaining: 760ms
# 210:	learn: 0.0637928	total: 553ms	remaining: 757ms
# 211:	learn: 0.0634227	total: 555ms	remaining: 755ms
# 212:	learn: 0.0630878	total: 558ms	remaining: 752ms
# 213:	learn: 0.0624521	total: 560ms	remaining: 749ms
# 214:	learn: 0.0618985	total: 563ms	remaining: 746ms
# 215:	learn: 0.0614868	total: 565ms	remaining: 744ms
# 216:	learn: 0.0606775	total: 568ms	remaining: 741ms
# 217:	learn: 0.0602558	total: 570ms	remaining: 738ms
# 218:	learn: 0.0598278	total: 573ms	remaining: 735ms
# 219:	learn: 0.0591661	total: 576ms	remaining: 733ms
# 220:	learn: 0.0585695	total: 578ms	remaining: 730ms
# 221:	learn: 0.0582572	total: 581ms	remaining: 727ms
# 222:	learn: 0.0579328	total: 583ms	remaining: 724ms
# 223:	learn: 0.0576205	total: 586ms	remaining: 722ms
# 224:	learn: 0.0572123	total: 590ms	remaining: 721ms
# 225:	learn: 0.0566304	total: 592ms	remaining: 718ms
# 226:	learn: 0.0563100	total: 595ms	remaining: 716ms
# 227:	learn: 0.0559225	total: 598ms	remaining: 713ms
# 228:	learn: 0.0554130	total: 600ms	remaining: 710ms
# 229:	learn: 0.0550796	total: 603ms	remaining: 708ms
# 230:	learn: 0.0547378	total: 605ms	remaining: 705ms
# 231:	learn: 0.0543491	total: 608ms	remaining: 702ms
# 232:	learn: 0.0538837	total: 610ms	remaining: 699ms
# 233:	learn: 0.0533203	total: 613ms	remaining: 696ms
# 234:	learn: 0.0526902	total: 615ms	remaining: 694ms
# 235:	learn: 0.0523920	total: 618ms	remaining: 691ms
# 236:	learn: 0.0521287	total: 620ms	remaining: 688ms
# 237:	learn: 0.0516752	total: 623ms	remaining: 685ms
# 238:	learn: 0.0514476	total: 625ms	remaining: 683ms
# 239:	learn: 0.0510832	total: 628ms	remaining: 680ms
# 240:	learn: 0.0508335	total: 630ms	remaining: 677ms
# 241:	learn: 0.0506276	total: 633ms	remaining: 675ms
# 242:	learn: 0.0502147	total: 636ms	remaining: 672ms
# 243:	learn: 0.0496969	total: 638ms	remaining: 669ms
# 244:	learn: 0.0490887	total: 642ms	remaining: 668ms
# 245:	learn: 0.0486944	total: 645ms	remaining: 666ms
# 246:	learn: 0.0483610	total: 648ms	remaining: 663ms
# 247:	learn: 0.0480897	total: 650ms	remaining: 661ms
# 248:	learn: 0.0477649	total: 653ms	remaining: 658ms
# 249:	learn: 0.0474518	total: 655ms	remaining: 655ms
# 250:	learn: 0.0468668	total: 658ms	remaining: 653ms
# 251:	learn: 0.0465662	total: 660ms	remaining: 650ms
# 252:	learn: 0.0463000	total: 663ms	remaining: 647ms
# 253:	learn: 0.0460433	total: 665ms	remaining: 644ms
# 254:	learn: 0.0457519	total: 667ms	remaining: 641ms
# 255:	learn: 0.0454585	total: 670ms	remaining: 638ms
# 256:	learn: 0.0450992	total: 672ms	remaining: 635ms
# 257:	learn: 0.0448284	total: 674ms	remaining: 632ms
# 258:	learn: 0.0444397	total: 676ms	remaining: 629ms
# 259:	learn: 0.0441482	total: 679ms	remaining: 627ms
# 260:	learn: 0.0437642	total: 682ms	remaining: 624ms
# 261:	learn: 0.0433927	total: 684ms	remaining: 622ms
# 262:	learn: 0.0431651	total: 687ms	remaining: 619ms
# 263:	learn: 0.0428813	total: 689ms	remaining: 616ms
# 264:	learn: 0.0425973	total: 692ms	remaining: 613ms
# 265:	learn: 0.0423282	total: 694ms	remaining: 611ms
# 266:	learn: 0.0420450	total: 696ms	remaining: 608ms
# 267:	learn: 0.0417605	total: 699ms	remaining: 605ms
# 268:	learn: 0.0413983	total: 701ms	remaining: 602ms
# 269:	learn: 0.0412397	total: 703ms	remaining: 599ms
# 270:	learn: 0.0409565	total: 706ms	remaining: 596ms
# 271:	learn: 0.0404780	total: 708ms	remaining: 593ms
# 272:	learn: 0.0400572	total: 710ms	remaining: 590ms
# 273:	learn: 0.0397397	total: 713ms	remaining: 588ms
# 274:	learn: 0.0393757	total: 715ms	remaining: 585ms
# 275:	learn: 0.0391405	total: 717ms	remaining: 582ms
# 276:	learn: 0.0388854	total: 720ms	remaining: 579ms
# 277:	learn: 0.0386804	total: 722ms	remaining: 577ms
# 278:	learn: 0.0384157	total: 724ms	remaining: 574ms
# 279:	learn: 0.0380339	total: 727ms	remaining: 571ms
# 280:	learn: 0.0377249	total: 729ms	remaining: 568ms
# 281:	learn: 0.0373518	total: 732ms	remaining: 566ms
# 282:	learn: 0.0371436	total: 734ms	remaining: 563ms
# 283:	learn: 0.0369766	total: 737ms	remaining: 560ms
# 284:	learn: 0.0366521	total: 739ms	remaining: 558ms
# 285:	learn: 0.0362901	total: 741ms	remaining: 555ms
# 286:	learn: 0.0360381	total: 744ms	remaining: 552ms
# 287:	learn: 0.0358031	total: 747ms	remaining: 550ms
# 288:	learn: 0.0356379	total: 749ms	remaining: 547ms
# 289:	learn: 0.0354053	total: 752ms	remaining: 544ms
# 290:	learn: 0.0352368	total: 754ms	remaining: 542ms
# 291:	learn: 0.0348938	total: 757ms	remaining: 539ms
# 292:	learn: 0.0345596	total: 759ms	remaining: 536ms
# 293:	learn: 0.0343399	total: 762ms	remaining: 534ms
# 294:	learn: 0.0340503	total: 764ms	remaining: 531ms
# 295:	learn: 0.0337718	total: 766ms	remaining: 528ms
# 296:	learn: 0.0334690	total: 769ms	remaining: 526ms
# 297:	learn: 0.0332047	total: 772ms	remaining: 523ms
# 298:	learn: 0.0329881	total: 774ms	remaining: 520ms
# 299:	learn: 0.0328006	total: 776ms	remaining: 518ms
# 300:	learn: 0.0326207	total: 779ms	remaining: 515ms
# 301:	learn: 0.0322896	total: 782ms	remaining: 513ms
# 302:	learn: 0.0321687	total: 786ms	remaining: 511ms
# 303:	learn: 0.0319534	total: 788ms	remaining: 508ms
# 304:	learn: 0.0318090	total: 791ms	remaining: 506ms
# 305:	learn: 0.0315117	total: 794ms	remaining: 503ms
# 306:	learn: 0.0312210	total: 796ms	remaining: 500ms
# 307:	learn: 0.0310161	total: 799ms	remaining: 498ms
# 308:	learn: 0.0309077	total: 801ms	remaining: 495ms
# 309:	learn: 0.0307378	total: 803ms	remaining: 492ms
# 310:	learn: 0.0305846	total: 806ms	remaining: 490ms
# 311:	learn: 0.0304270	total: 808ms	remaining: 487ms
# 312:	learn: 0.0302178	total: 810ms	remaining: 484ms
# 313:	learn: 0.0300347	total: 813ms	remaining: 482ms
# 314:	learn: 0.0298159	total: 815ms	remaining: 479ms
# 315:	learn: 0.0295583	total: 818ms	remaining: 476ms
# 316:	learn: 0.0294345	total: 820ms	remaining: 473ms
# 317:	learn: 0.0292967	total: 822ms	remaining: 471ms
# 318:	learn: 0.0291778	total: 825ms	remaining: 468ms
# 319:	learn: 0.0289313	total: 827ms	remaining: 465ms
# 320:	learn: 0.0287928	total: 830ms	remaining: 463ms
# 321:	learn: 0.0285906	total: 832ms	remaining: 460ms
# 322:	learn: 0.0283470	total: 835ms	remaining: 458ms
# 323:	learn: 0.0282135	total: 838ms	remaining: 455ms
# 324:	learn: 0.0279939	total: 841ms	remaining: 453ms
# 325:	learn: 0.0278965	total: 844ms	remaining: 450ms
# 326:	learn: 0.0276640	total: 846ms	remaining: 448ms
# 327:	learn: 0.0274657	total: 849ms	remaining: 445ms
# 328:	learn: 0.0272511	total: 851ms	remaining: 442ms
# 329:	learn: 0.0270149	total: 853ms	remaining: 440ms
# 330:	learn: 0.0267864	total: 856ms	remaining: 437ms
# 331:	learn: 0.0266826	total: 858ms	remaining: 434ms
# 332:	learn: 0.0265135	total: 861ms	remaining: 432ms
# 333:	learn: 0.0262769	total: 863ms	remaining: 429ms
# 334:	learn: 0.0260718	total: 866ms	remaining: 426ms
# 335:	learn: 0.0258794	total: 868ms	remaining: 424ms
# 336:	learn: 0.0257761	total: 871ms	remaining: 421ms
# 337:	learn: 0.0255649	total: 873ms	remaining: 418ms
# 338:	learn: 0.0253923	total: 876ms	remaining: 416ms
# 339:	learn: 0.0252053	total: 878ms	remaining: 413ms
# 340:	learn: 0.0250335	total: 880ms	remaining: 411ms
# 341:	learn: 0.0248529	total: 883ms	remaining: 408ms
# 342:	learn: 0.0247544	total: 885ms	remaining: 405ms
# 343:	learn: 0.0244147	total: 888ms	remaining: 403ms
# 344:	learn: 0.0242637	total: 890ms	remaining: 400ms
# 345:	learn: 0.0239888	total: 893ms	remaining: 397ms
# 346:	learn: 0.0237958	total: 895ms	remaining: 395ms
# 347:	learn: 0.0236107	total: 898ms	remaining: 392ms
# 348:	learn: 0.0233857	total: 900ms	remaining: 389ms
# 349:	learn: 0.0232593	total: 902ms	remaining: 387ms
# 350:	learn: 0.0231381	total: 905ms	remaining: 384ms
# 351:	learn: 0.0229660	total: 907ms	remaining: 381ms
# 352:	learn: 0.0228204	total: 910ms	remaining: 379ms
# 353:	learn: 0.0226702	total: 912ms	remaining: 376ms
# 354:	learn: 0.0225195	total: 915ms	remaining: 374ms
# 355:	learn: 0.0223661	total: 917ms	remaining: 371ms
# 356:	learn: 0.0222622	total: 919ms	remaining: 368ms
# 357:	learn: 0.0220674	total: 922ms	remaining: 366ms
# 358:	learn: 0.0218918	total: 924ms	remaining: 363ms
# 359:	learn: 0.0217581	total: 927ms	remaining: 360ms
# 360:	learn: 0.0215982	total: 929ms	remaining: 358ms
# 361:	learn: 0.0214780	total: 932ms	remaining: 355ms
# 362:	learn: 0.0214278	total: 934ms	remaining: 352ms
# 363:	learn: 0.0212509	total: 936ms	remaining: 350ms
# 364:	learn: 0.0211625	total: 939ms	remaining: 347ms
# 365:	learn: 0.0210855	total: 941ms	remaining: 345ms
# 366:	learn: 0.0209218	total: 944ms	remaining: 342ms
# 367:	learn: 0.0207348	total: 946ms	remaining: 339ms
# 368:	learn: 0.0205944	total: 949ms	remaining: 337ms
# 369:	learn: 0.0204592	total: 951ms	remaining: 334ms
# 370:	learn: 0.0203321	total: 953ms	remaining: 332ms
# 371:	learn: 0.0202227	total: 956ms	remaining: 329ms
# 372:	learn: 0.0201154	total: 958ms	remaining: 326ms
# 373:	learn: 0.0200324	total: 961ms	remaining: 324ms
# 374:	learn: 0.0198683	total: 963ms	remaining: 321ms
# 375:	learn: 0.0197256	total: 966ms	remaining: 318ms
# 376:	learn: 0.0195499	total: 968ms	remaining: 316ms
# 377:	learn: 0.0194484	total: 970ms	remaining: 313ms
# 378:	learn: 0.0193730	total: 973ms	remaining: 311ms
# 379:	learn: 0.0192254	total: 976ms	remaining: 308ms
# 380:	learn: 0.0191172	total: 980ms	remaining: 306ms
# 381:	learn: 0.0190731	total: 982ms	remaining: 303ms
# 382:	learn: 0.0188934	total: 985ms	remaining: 301ms
# 383:	learn: 0.0187365	total: 987ms	remaining: 298ms
# 384:	learn: 0.0185976	total: 990ms	remaining: 296ms
# 385:	learn: 0.0184941	total: 993ms	remaining: 293ms
# 386:	learn: 0.0183780	total: 995ms	remaining: 291ms
# 387:	learn: 0.0183181	total: 998ms	remaining: 288ms
# 388:	learn: 0.0181747	total: 1s	remaining: 285ms
# 389:	learn: 0.0180542	total: 1s	remaining: 283ms
# 390:	learn: 0.0179011	total: 1s	remaining: 280ms
# 391:	learn: 0.0177289	total: 1.01s	remaining: 278ms
# 392:	learn: 0.0175485	total: 1.01s	remaining: 275ms
# 393:	learn: 0.0174352	total: 1.01s	remaining: 272ms
# 394:	learn: 0.0173514	total: 1.01s	remaining: 270ms
# 395:	learn: 0.0172465	total: 1.02s	remaining: 267ms
# 396:	learn: 0.0171201	total: 1.02s	remaining: 265ms
# 397:	learn: 0.0169787	total: 1.02s	remaining: 262ms
# 398:	learn: 0.0168714	total: 1.02s	remaining: 259ms
# 399:	learn: 0.0167537	total: 1.03s	remaining: 257ms
# 400:	learn: 0.0167081	total: 1.03s	remaining: 255ms
# 401:	learn: 0.0166051	total: 1.03s	remaining: 252ms
# 402:	learn: 0.0165386	total: 1.04s	remaining: 250ms
# 403:	learn: 0.0164844	total: 1.04s	remaining: 247ms
# 404:	learn: 0.0163876	total: 1.04s	remaining: 244ms
# 405:	learn: 0.0162844	total: 1.04s	remaining: 242ms
# 406:	learn: 0.0161929	total: 1.05s	remaining: 239ms
# 407:	learn: 0.0160501	total: 1.05s	remaining: 237ms
# 408:	learn: 0.0159154	total: 1.05s	remaining: 234ms
# 409:	learn: 0.0158392	total: 1.05s	remaining: 232ms
# 410:	learn: 0.0157292	total: 1.06s	remaining: 229ms
# 411:	learn: 0.0155773	total: 1.06s	remaining: 226ms
# 412:	learn: 0.0154929	total: 1.06s	remaining: 224ms
# 413:	learn: 0.0154299	total: 1.06s	remaining: 221ms
# 414:	learn: 0.0153453	total: 1.07s	remaining: 219ms
# 415:	learn: 0.0152657	total: 1.07s	remaining: 216ms
# 416:	learn: 0.0151865	total: 1.07s	remaining: 214ms
# 417:	learn: 0.0150787	total: 1.07s	remaining: 211ms
# 418:	learn: 0.0150070	total: 1.08s	remaining: 208ms
# 419:	learn: 0.0148890	total: 1.08s	remaining: 206ms
# 420:	learn: 0.0147949	total: 1.08s	remaining: 203ms
# 421:	learn: 0.0147495	total: 1.09s	remaining: 201ms
# 422:	learn: 0.0146889	total: 1.09s	remaining: 198ms
# 423:	learn: 0.0146134	total: 1.09s	remaining: 196ms
# 424:	learn: 0.0145199	total: 1.09s	remaining: 193ms
# 425:	learn: 0.0144162	total: 1.1s	remaining: 191ms
# 426:	learn: 0.0143354	total: 1.1s	remaining: 188ms
# 427:	learn: 0.0142811	total: 1.1s	remaining: 185ms
# 428:	learn: 0.0141963	total: 1.1s	remaining: 183ms
# 429:	learn: 0.0141074	total: 1.11s	remaining: 180ms
# 430:	learn: 0.0140443	total: 1.11s	remaining: 178ms
# 431:	learn: 0.0139959	total: 1.11s	remaining: 175ms
# 432:	learn: 0.0138932	total: 1.11s	remaining: 173ms
# 433:	learn: 0.0137864	total: 1.12s	remaining: 170ms
# 434:	learn: 0.0136853	total: 1.12s	remaining: 167ms
# 435:	learn: 0.0135680	total: 1.12s	remaining: 165ms
# 436:	learn: 0.0134985	total: 1.13s	remaining: 162ms
# 437:	learn: 0.0134267	total: 1.13s	remaining: 160ms
# 438:	learn: 0.0133440	total: 1.13s	remaining: 157ms
# 439:	learn: 0.0133014	total: 1.13s	remaining: 154ms
# 440:	learn: 0.0132288	total: 1.14s	remaining: 152ms
# 441:	learn: 0.0131475	total: 1.14s	remaining: 149ms
# 442:	learn: 0.0130402	total: 1.14s	remaining: 147ms
# 443:	learn: 0.0129584	total: 1.14s	remaining: 144ms
# 444:	learn: 0.0128943	total: 1.15s	remaining: 142ms
# 445:	learn: 0.0128488	total: 1.15s	remaining: 139ms
# 446:	learn: 0.0127956	total: 1.15s	remaining: 136ms
# 447:	learn: 0.0126813	total: 1.15s	remaining: 134ms
# 448:	learn: 0.0126374	total: 1.16s	remaining: 131ms
# 449:	learn: 0.0126133	total: 1.16s	remaining: 129ms
# 450:	learn: 0.0125455	total: 1.16s	remaining: 126ms
# 451:	learn: 0.0124916	total: 1.16s	remaining: 124ms
# 452:	learn: 0.0124254	total: 1.17s	remaining: 121ms
# 453:	learn: 0.0123704	total: 1.17s	remaining: 118ms
# 454:	learn: 0.0122755	total: 1.17s	remaining: 116ms
# 455:	learn: 0.0122090	total: 1.18s	remaining: 113ms
# 456:	learn: 0.0121196	total: 1.18s	remaining: 111ms
# 457:	learn: 0.0120969	total: 1.18s	remaining: 108ms
# 458:	learn: 0.0120314	total: 1.18s	remaining: 106ms
# 459:	learn: 0.0119679	total: 1.19s	remaining: 103ms
# 460:	learn: 0.0118791	total: 1.19s	remaining: 101ms
# 461:	learn: 0.0118279	total: 1.19s	remaining: 98ms
# 462:	learn: 0.0117878	total: 1.19s	remaining: 95.4ms
# 463:	learn: 0.0116883	total: 1.2s	remaining: 92.8ms
# 464:	learn: 0.0116296	total: 1.2s	remaining: 90.2ms
# 465:	learn: 0.0115528	total: 1.2s	remaining: 87.7ms
# 466:	learn: 0.0115226	total: 1.2s	remaining: 85.1ms
# 467:	learn: 0.0114461	total: 1.21s	remaining: 82.5ms
# 468:	learn: 0.0113896	total: 1.21s	remaining: 79.9ms
# 469:	learn: 0.0113165	total: 1.21s	remaining: 77.3ms
# 470:	learn: 0.0112780	total: 1.21s	remaining: 74.7ms
# 471:	learn: 0.0112058	total: 1.22s	remaining: 72.2ms
# 472:	learn: 0.0111535	total: 1.22s	remaining: 69.6ms
# 473:	learn: 0.0111163	total: 1.22s	remaining: 67ms
# 474:	learn: 0.0110503	total: 1.23s	remaining: 64.5ms
# 475:	learn: 0.0110077	total: 1.23s	remaining: 61.9ms
# 476:	learn: 0.0109256	total: 1.23s	remaining: 59.3ms
# 477:	learn: 0.0108813	total: 1.23s	remaining: 56.8ms
# 478:	learn: 0.0108260	total: 1.24s	remaining: 54.2ms
# 479:	learn: 0.0108106	total: 1.24s	remaining: 51.6ms
# 480:	learn: 0.0107525	total: 1.24s	remaining: 49ms
# 481:	learn: 0.0106625	total: 1.24s	remaining: 46.4ms
# 482:	learn: 0.0106168	total: 1.25s	remaining: 43.8ms
# 483:	learn: 0.0105898	total: 1.25s	remaining: 41.2ms
# 484:	learn: 0.0105587	total: 1.25s	remaining: 38.6ms
# 485:	learn: 0.0104998	total: 1.25s	remaining: 36.1ms
# 486:	learn: 0.0104524	total: 1.25s	remaining: 33.5ms
# 487:	learn: 0.0103584	total: 1.26s	remaining: 30.9ms
# 488:	learn: 0.0102987	total: 1.26s	remaining: 28.3ms
# 489:	learn: 0.0102504	total: 1.26s	remaining: 25.7ms
# 490:	learn: 0.0101661	total: 1.26s	remaining: 23.2ms
# 491:	learn: 0.0100928	total: 1.27s	remaining: 20.6ms
# 492:	learn: 0.0100669	total: 1.27s	remaining: 18ms
# 493:	learn: 0.0100241	total: 1.27s	remaining: 15.4ms
# 494:	learn: 0.0099893	total: 1.27s	remaining: 12.9ms
# 495:	learn: 0.0099074	total: 1.28s	remaining: 10.3ms
# 496:	learn: 0.0098689	total: 1.28s	remaining: 7.72ms
# 497:	learn: 0.0098339	total: 1.28s	remaining: 5.15ms
# 498:	learn: 0.0097576	total: 1.28s	remaining: 2.57ms
# 499:	learn: 0.0097028	total: 1.29s	remaining: 0us

# %%
sample_submission.head()
# Out:
#              Id  class_0  class_1
# 0  00eed32682bb      0.5      0.5
# 1  010ebe33f668      0.5      0.5
# 2  02fa521e1838      0.5      0.5
# 3  040e15f562a2      0.5      0.5
# 4  046e85c7cc7f      0.5      0.5

# %%
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=column_names)
X_test = X_test_scaled

# %%
X_test_filtered = X_test[selected_features]
X_test = X_test_filtered

# %%
pred_probs = model.predict_proba(X_test)

data = {'Id': test.Id, 'class_0': pred_probs[:, 0], 'class_1': pred_probs[:, 1]}
df = pd.DataFrame(data)
print(df.head())
# Out:
#              Id   class_0   class_1
# 0  00eed32682bb  0.998247  0.001753
# 1  010ebe33f668  0.998247  0.001753
# 2  02fa521e1838  0.998247  0.001753
# 3  040e15f562a2  0.998247  0.001753
# 4  046e85c7cc7f  0.998247  0.001753

# %%
df.to_csv('submission.csv', index=False)
